# %% [markdown]
# #**Mathematics in Machine Learning - Part 2 Preparation & Models**
#
# Politecnico di Torino
#
# Alberto Maria Falletta S277971

# %% [markdown]
# **Imports**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_style("whitegrid")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **IRRELEVANT FEATURES REMOVAL**

# %%
path = "/content/bank-additional-full.csv"
pd.set_option("display.max_columns", None)

df = pd.read_csv(path, delimiter=';')

# Mapping '999' (= never contacted) to '-1' for visualization reasons
df['pdays'] = df['pdays'].replace(999, -1)

print(f"Total number of 'unknown' values before columns dropping: {len(df[(df['job'] == 'unknown')]) + len(df[(df['marital'] == 'unknown')]) + len(df[(df['education'] == 'unknown')]) + len(df[(df['housing'] == 'unknown')])}")
print(f"Number of records with at least one 'unknown' value before columns dropping: {len(df[(df['job'] == 'unknown') | (df['marital']== 'unknown') | (df['education']== 'unknown') | (df['housing']== 'unknown') ])}")
print(f"Total number of elements: {df.shape}", "\n")

df = df.drop(['duration', 'default', 'loan'], axis=1)

print(f"Dataset total number of records: {df.shape}")
print(f"Presence of Nan values: {df.isnull().values.any()}")
print(f"Total number of 'unknown' values: {len(df[(df['job'] == 'unknown')]) + len(df[(df['marital'] == 'unknown')]) + len(df[(df['education'] == 'unknown')]) + len(df[(df['housing'] == 'unknown')])}")
print(f"Number of records with at least one 'unknown' value: {len(df[(df['job'] == 'unknown') | (df['marital']== 'unknown') | (df['education']== 'unknown') | (df['housing']== 'unknown') ])}")
print(f"Total number of elements: {df.shape}", "\n")

df_yes = df[df['y'] == "yes"]
df_no = df[df['y'] == "no"]

print(f"Total number of 'unknown' values for Yes: {len(df_yes[(df_yes['job'] == 'unknown')]) + len(df_yes[(df_yes['marital'] == 'unknown')]) + len(df_yes[(df_yes['education'] == 'unknown')]) + len(df_yes[(df_yes['housing'] == 'unknown')])}")
print(f"Number of records with at least one 'unknown' value for Yes: {len(df_yes[(df_yes['job'] == 'unknown') | (df_yes['marital']== 'unknown') | (df_yes['education']== 'unknown') | (df_yes['housing']== 'unknown') ])}")
print(f"Total number of elements for Yes: {df_yes.shape}", "\n")

print(f"Total number of 'unknown' values for No: {len(df_no[(df_no['job'] == 'unknown')]) + len(df_no[(df_no['marital'] == 'unknown')]) + len(df_no[(df_no['education'] == 'unknown')]) + len(df_no[(df_no['housing'] == 'unknown')])}")
print(f"Number of records with at least one 'unknown' value for No: {len(df_no[(df_no['job'] == 'unknown') | (df_no['marital']== 'unknown') | (df_no['education']== 'unknown') | (df_no['housing']== 'unknown') ])}")
print(f"Total number of elements for No: {df_no.shape}", "\n")
# Out:
# Total number of 'unknown' values before columns dropping: 3131
# Number of records with at least one 'unknown' value before columns dropping: 2943
# Total number of elements: (41188, 21)
#
# Dataset total number of records: (41188, 18)
# Presence of Nan values: False
# Total number of 'unknown' values: 3131
# Number of records with at least one 'unknown' value: 2943
# Total number of elements: (41188, 18)
#
# Total number of 'unknown' values for Yes: 407
# Number of records with at least one 'unknown' value for Yes: 382
# Total number of elements for Yes: (4640, 18)
#
# Total number of 'unknown' values for No: 2724
# Number of records with at least one 'unknown' value for No: 2561
# Total number of elements for No: (36548, 18)

# %% [markdown]
# **OUTLIERS REMOVAL**

# %%
print(f"Total number of removed outliers for Yes: {df_yes[df_yes['age'] >= 79].shape}")
df_yes = df_yes[df_yes['age'] < 79]
print(f"Total number of removed outliers for No: {df_no[df_no['age'] >= 70].shape}", "\n")
df_no = df_no[df_no['age'] < 70] 

df = pd.concat([df_no, df_yes])
print(f"Number of records after outliers removal: {df.shape}")

print(f"Total number of 'unknown' values for Yes: {len(df_yes[(df_yes['job'] == 'unknown')]) + len(df_yes[(df_yes['marital'] == 'unknown')]) + len(df_yes[(df_yes['education'] == 'unknown')]) + len(df_yes[(df_yes['housing'] == 'unknown')])}")
print(f"Number of records with at least one 'unknown' value for Yes: {len(df_yes[(df_yes['job'] == 'unknown') | (df_yes['marital']== 'unknown') | (df_yes['education']== 'unknown') | (df_yes['housing']== 'unknown') ])}")
print(f"Total number of elements for Yes: {df_yes.shape}", "\n")

print(f"Total number of 'unknown' values for No: {len(df_no[(df_no['job'] == 'unknown')]) + len(df_no[(df_no['marital'] == 'unknown')]) + len(df_no[(df_no['education'] == 'unknown')]) + len(df_no[(df_no['housing'] == 'unknown')])}")
print(f"Number of records with at least one 'unknown' value for No: {len(df_no[(df_no['job'] == 'unknown') | (df_no['marital']== 'unknown') | (df_no['education']== 'unknown') | (df_no['housing']== 'unknown') ])}")
print(f"Total number of elements for No: {df_no.shape}", "\n")
# Out:
# Total number of removed outliers for Yes: (84, 18)
# Total number of removed outliers for No: (248, 18)
#
# Number of records after outliers removal: (40856, 18)
# Total number of 'unknown' values for Yes: 393
# Number of records with at least one 'unknown' value for Yes: 370
# Total number of elements for Yes: (4556, 18)
#
# Total number of 'unknown' values for No: 2702
# Number of records with at least one 'unknown' value for No: 2540
# Total number of elements for No: (36300, 18)

# %% [markdown]
# **UNKNOWN VALUES REMOVAL**

# %%
print(f"Number of records to be removed: {df[(df['job'] == 'unknown') | (df['marital']== 'unknown') | (df['education']== 'unknown') | (df['housing']== 'unknown')].shape}")
df = df[(df['job'] != 'unknown') & (df['marital'] != 'unknown') & (df['education'] != 'unknown') & (df['housing'] != 'unknown')]
print(f"Number of records and features: {df.shape}")
# Out:
# Number of records to be removed: (2910, 18)
# Number of records and features: (37946, 18)

# %% [markdown]
# **ONE HOT ENCODING**

# %%
# Categorical variables encoding
df = pd.concat([df, pd.get_dummies(df['job'], prefix='job')], axis=1).drop(['job'], axis=1)
df = pd.concat([df, pd.get_dummies(df['marital'], prefix='marital')], axis=1).drop(['marital'], axis=1)
df = pd.concat([df, pd.get_dummies(df['education'], prefix='education')], axis=1).drop(['education'], axis=1)
df = pd.concat([df, pd.get_dummies(df['housing'], prefix='housing')], axis=1).drop(['housing'], axis=1)
df = pd.concat([df, pd.get_dummies(df['contact'], prefix='contact')], axis=1).drop(['contact'], axis=1)
df = pd.concat([df, pd.get_dummies(df['month'], prefix='month')], axis=1).drop(['month'], axis=1)
df = pd.concat([df, pd.get_dummies(df['day_of_week'], prefix='day_of_week')], axis=1).drop(['day_of_week'], axis=1)
df = pd.concat([df, pd.get_dummies(df['poutcome'], prefix='poutcome')], axis=1).drop(['poutcome'], axis=1)

# Class variable encoding
df.loc[df["y"] == 'yes', "y"] = 1
df.loc[df["y"] == 'no', "y"] = 0

# Prints
print(f"Number of records class 'Yes': {len(df[df['y'] == 1])}")
print(f"Number of records class 'No': {len(df[df['y'] == 0])}")
# print(df.head(), "\n")
print(f"Number of records and features: {df.shape}")
# Out:
# Number of records class 'Yes': 4186
# Number of records class 'No': 33760
# Number of records and features: (37946, 53)

# %% [markdown]
# **TRAINING + VALIDATION & TEST SPLITS**

# %%
# Division in training-validation and test sets mantaining proportions
df_yes = df[df['y'] == 1].sample(frac=1)
df_no = df[df['y'] == 0].sample(frac=1)

df_yes_train_valid = df_yes.iloc[837:, : ]  
df_yes_test = df_yes.iloc[:837, :]  # 837 is 20 % 

df_no_train_valid = df_no.iloc[6752:, : ]
df_no_test = df_no.iloc[:6752, :]  # 6752 is 20 %

# Train-Valid set creation and shuffle
df_train_valid = pd.concat([df_yes_train_valid, df_no_train_valid]).sample(frac=1)

# Test set creation and shuffle + partition data & labels
df_test = pd.concat([df_yes_test, df_no_test]).sample(frac=1)
y_test = df_test['y'].astype('int')
df_test = df_test.drop('y', axis=1)

print(df_train_valid.shape)
# Out:
# (30357, 53)

# %% [markdown]
# **CUSTOM CROSS-VALIDATION, OVER-SAMPLING AND MODELS**

# %%
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, recall_score
from sklearn.model_selection import ParameterGrid
import json

df_yes = df_train_valid[df_train_valid['y'] == 1].sample(frac=1)
df_no = df_train_valid[df_train_valid['y'] == 0].sample(frac=1)

# 5 Folds with equal proportionality of classes
step_yes = len(df_yes) // 5
df_yes_1 = df_yes.iloc[:step_yes, : ]
df_yes_2 = df_yes.iloc[step_yes:2*step_yes, : ]
df_yes_3 = df_yes.iloc[2*step_yes:3*step_yes, : ]
df_yes_4 = df_yes.iloc[3*step_yes:4*step_yes, : ]
df_yes_5 = df_yes.iloc[4*step_yes:, : ]

step_no = len(df_no) // 5
df_no_1 = df_no.iloc[:step_no, : ]
df_no_2 = df_no.iloc[step_no:2*step_no, : ]
df_no_3 = df_no.iloc[2*step_no:3*step_no, : ]
df_no_4 = df_no.iloc[3*step_no:4*step_no, : ]
df_no_5 = df_no.iloc[4*step_no:, : ]

df_train_valid_1 = pd.concat([df_yes_1, df_no_1]).sample(frac=1)
df_train_valid_2 = pd.concat([df_yes_2, df_no_2]).sample(frac=1)
df_train_valid_3 = pd.concat([df_yes_3, df_no_3]).sample(frac=1)
df_train_valid_4 = pd.concat([df_yes_4, df_no_4]).sample(frac=1)
df_train_valid_5 = pd.concat([df_yes_5, df_no_5]).sample(frac=1)

cl1_accuracy = {}
cl2_accuracy = {}
cl3_accuracy = {}
cl4_accuracy = {}

cl1_recall = {}
cl2_recall = {}
cl3_recall = {}
cl4_recall = {}
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# Training 1 -------------------------------------------------------------------
print("Training 1")
# Datasets composition
df_train = pd.concat([df_train_valid_1, df_train_valid_2, df_train_valid_3, df_train_valid_4]).sample(frac=1)
df_valid = df_train_valid_5

# Variables separation
y = df_train['y']
X = df_train.drop('y', axis=1)
y_valid = df_valid['y'].astype('int')
X_valid = df_valid.drop('y', axis=1)

# Oversampling
X_oversampled, y_oversampled = SMOTE().fit_resample(X, y)
X_oversampled = pd.DataFrame(X_oversampled, columns=X.columns)
y_oversampled = pd.DataFrame(y_oversampled, columns=["y"]).astype('int')

# Training
print("\n", "clf1", "\n")
hyp_parameters = {
  "penalty": ["l1", "l2"],
  "C": [1, 10, 100],
  "max_iter": [1000]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_1 = LogisticRegression()
  clf_1.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_1 = clf_1.predict(X_valid)
  cl1_accuracy[json.dumps(config)] = accuracy_score(y_valid, y_pred_1)
  cl1_recall[json.dumps(config)] = recall_score(y_valid, y_pred_1, pos_label=1)

print("\n", "clf2", "\n")
hyp_parameters = {
  "criterion": ["gini", "entropy"],
  "max_depth": [None, 15],
  "max_features": [None, "sqrt"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_2 = DecisionTreeClassifier(**config)
  clf_2.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_2 = clf_2.predict(X_valid)
  cl2_accuracy[json.dumps(config)] = accuracy_score(y_valid, y_pred_2)
  cl2_recall[json.dumps(config)] = recall_score(y_valid, y_pred_2, pos_label=1)

print("\n", "clf3", "\n")
hyp_parameters = {
  "criterion": ["gini", "entropy"],
  "n_estimators": [100],
  "max_depth": [None, 15],
  "max_features": [None, "sqrt"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_3 = RandomForestClassifier(**config)
  clf_3.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_3 = clf_3.predict(X_valid)
  cl3_accuracy[json.dumps(config)] = accuracy_score(y_valid, y_pred_3)
  cl3_recall[json.dumps(config)] = recall_score(y_valid, y_pred_3, pos_label=1)

print("\n", "clf4", "\n")
hyp_parameters = {
  "C": [1, 50],
  "kernel": ["linear", "rbf"],
  "gamma": ["scale", "auto"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_4 = SVC(**config)
  clf_4.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_4 = clf_4.predict(X_valid)
  cl4_accuracy[json.dumps(config)] = accuracy_score(y_valid, y_pred_4)
  cl4_recall[json.dumps(config)] = recall_score(y_valid, y_pred_4, pos_label=1)

print("\n", "TRAINING 1 RESULTS", "\n")
print(cl1_accuracy)
print(cl2_accuracy)
print(cl3_accuracy)
print(cl4_accuracy)

print(cl1_recall)
print(cl2_recall)
print(cl3_recall)
print(cl4_recall)
# Out:
# /usr/local/lib/python3.6/dist-packages/imblearn/utils/_validation.py:93: UserWarning: 'y' should be of types ('binary', 'multiclass', 'multilabel-indicator') only. Got unknown instead.
#   TARGET_KIND, type_of_target(y)))
# Training 1
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
#  clf1
#
# Current training: {'C': 1, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 1, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 10, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 10, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 100, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 100, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#  clf2
#
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': None}
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt'}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': None}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt'}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': None}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt'}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': None}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt'}
#
#  clf3
#
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 100}
#
#  clf4
#
# Current training: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Current training: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Current training: {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# Current training: {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# Current training: {'C': 50, 'gamma': 'scale', 'kernel': 'linear'}
# Current training: {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}
# Current training: {'C': 50, 'gamma': 'auto', 'kernel': 'linear'}
# Current training: {'C': 50, 'gamma': 'auto', 'kernel': 'rbf'}
#
#  TRAINING 1 RESULTS
#
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 0.8184959684054632, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 0.8184959684054632, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 0.8184959684054632, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 0.8184959684054632, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 0.8184959684054632, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 0.8184959684054632}
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 0.8393944380450881, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 0.860457462563765, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 0.8856343590587461, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 0.8691788711535297, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 0.8471285173605397, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 0.8612802369590258, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 0.8851406944215896, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 0.8762547309527727}
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 0.8946848774066151, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 0.8963304261971368, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 0.8984696396248149, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 0.8973177554714498, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 0.8958367615599803, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 0.8958367615599803, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 0.8984696396248149, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 0.8986341945038671}
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 0.8685206516373211, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 0.7243705775876255, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 0.8685206516373211, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 0.8357742307059405, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 0.8681915418792168, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 0.7243705775876255, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 0.8681915418792168, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 0.8532170478854698}
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 0.6285289747399703, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 0.6285289747399703, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 0.6285289747399703, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 0.6285289747399703, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 0.6285289747399703, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 0.6285289747399703}
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 0.35066864784546803, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 0.37444279346210996, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 0.3789004457652303, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 0.41901931649331353, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 0.3774145616641902, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 0.35066864784546803, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 0.39078751857355126, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 0.3640416047548291}
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 0.35066864784546803, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 0.3521545319465082, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 0.3863298662704309, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 0.42050520059435365, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 0.35066864784546803, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 0.3462109955423477, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 0.3922734026745914, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 0.4294205052005943}
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 0.5334323922734027, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 0.7102526002971769, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 0.5334323922734027, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 0.6136701337295691, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 0.5334323922734027, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 0.7102526002971769, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 0.5334323922734027, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 0.34323922734026746}

# %%
# Training 2 -------------------------------------------------------------------
print("Training 2")
# Datasets composition
df_train = pd.concat([df_train_valid_1, df_train_valid_2, df_train_valid_3, df_train_valid_5]).sample(frac=1)
df_valid = df_train_valid_4

# Variables separation
y = df_train['y']
X = df_train.drop('y', axis=1)
y_valid = df_valid['y'].astype('int')
X_valid = df_valid.drop('y', axis=1)

# Oversampling
X_oversampled, y_oversampled = SMOTE().fit_resample(X, y)
X_oversampled = pd.DataFrame(X_oversampled, columns=X.columns)
y_oversampled = pd.DataFrame(y_oversampled, columns=["y"]).astype('int')

# Training
print("\n", "clf1", "\n")
hyp_parameters = {
  "penalty": ["l1", "l2"],
  "C": [1, 10, 100],
  "max_iter": [1000]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_1 = LogisticRegression()
  clf_1.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_1 = clf_1.predict(X_valid)
  cl1_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_1)
  cl1_recall[json.dumps(config)] += recall_score(y_valid, y_pred_1, pos_label=1)

print("\n", "clf2", "\n")
hyp_parameters = {
  "criterion": ["gini", "entropy"],
  "max_depth": [None, 15],
  "max_features": [None, "sqrt"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_2 = DecisionTreeClassifier(**config)
  clf_2.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_2 = clf_2.predict(X_valid)
  cl2_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_2)
  cl2_recall[json.dumps(config)] += recall_score(y_valid, y_pred_2, pos_label=1)

print("\n", "clf3", "\n")
hyp_parameters = {
  "criterion": ["gini", "entropy"],
  "n_estimators": [100],
  "max_depth": [None, 15],
  "max_features": [None, "sqrt"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_3 = RandomForestClassifier(**config)
  clf_3.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_3 = clf_3.predict(X_valid)
  cl3_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_3)
  cl3_recall[json.dumps(config)] += recall_score(y_valid, y_pred_3, pos_label=1)

print("\n", "clf4", "\n")
hyp_parameters = {
  "C": [1, 50],
  "kernel": ["linear", "rbf"],
  "gamma": ["scale", "auto"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_4 = SVC(**config)
  clf_4.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_4 = clf_4.predict(X_valid)
  cl4_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_4)
  cl4_recall[json.dumps(config)] += recall_score(y_valid, y_pred_4, pos_label=1)

print("\n", "TRAINING 2 RESULTS", "\n")
print(cl1_accuracy)
print(cl2_accuracy)
print(cl3_accuracy)
print(cl4_accuracy)

print(cl1_recall)
print(cl2_recall)
print(cl3_recall)
print(cl4_recall)
# Out:
# Training 2
# /usr/local/lib/python3.6/dist-packages/imblearn/utils/_validation.py:93: UserWarning: 'y' should be of types ('binary', 'multiclass', 'multilabel-indicator') only. Got unknown instead.
#   TARGET_KIND, type_of_target(y)))
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
#  clf1
#
# Current training: {'C': 1, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 1, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 10, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 10, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 100, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 100, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#  clf2
#
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': None}
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt'}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': None}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt'}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': None}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt'}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': None}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt'}
#
#  clf3
#
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 100}
#
#  clf4
#
# Current training: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Current training: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Current training: {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# Current training: {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# Current training: {'C': 50, 'gamma': 'scale', 'kernel': 'linear'}
# Current training: {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}
# Current training: {'C': 50, 'gamma': 'auto', 'kernel': 'linear'}
# Current training: {'C': 50, 'gamma': 'auto', 'kernel': 'rbf'}
#
#  TRAINING 2 RESULTS
#
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 1.6392537937761387, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 1.6392537937761387, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 1.6392537937761387, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 1.6392537937761387, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 1.6392537937761387, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 1.6392537937761387}
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 1.68074534414064, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 1.7161411528438308, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 1.7645470443964726, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 1.7385363670349134, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 1.6991878254330275, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 1.709056184240739, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 1.7652065922799092, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 1.721559508547501}
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 1.7869418790540617, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 1.784798300991206, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 1.7917151091470553, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 1.7907279696394893, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 1.7892469757280198, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 1.7890822310822208, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 1.7930330663134475, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 1.7927033872551026}
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 1.7278287241249652, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 1.4438104457919088, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 1.7278287241249652, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 1.6743244778229092, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 1.729970784053846, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 1.4438104457919088, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 1.729970784053846, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 1.7028051862709723}
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 1.2398892139029, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 1.2398892139029, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 1.2398892139029, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 1.2398892139029, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 1.2398892139029, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 1.2398892139029}
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 0.7004444325988313, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 0.7122604317281787, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 0.7077494741658282, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 0.8166276871958547, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 0.739148492904848, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 0.6735386030024186, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 0.7256156202177964, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 0.7616499754573702}
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 0.6959601276660958, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 0.682498328658018, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 0.7405899559565297, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 0.8420298642714836, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 0.6989496642879194, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 0.6915024753629755, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 0.7555021022261609, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 0.8419765590122535}
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 1.0580960694034474, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 1.3993407916275207, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 1.0580960694034474, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 1.1831768601869683, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 1.062580374336183, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 1.3993407916275207, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 1.062580374336183, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 0.6885307071608953}

# %%
# Training 3 -------------------------------------------------------------------
print("Training 3")
# Datasets composition
df_train = pd.concat([df_train_valid_1, df_train_valid_2, df_train_valid_4, df_train_valid_5]).sample(frac=1)
df_valid = df_train_valid_3

# Variables separation
y = df_train['y']
X = df_train.drop('y', axis=1)
y_valid = df_valid['y'].astype('int')
X_valid = df_valid.drop('y', axis=1)

# Oversampling
X_oversampled, y_oversampled = SMOTE().fit_resample(X, y)
X_oversampled = pd.DataFrame(X_oversampled, columns=X.columns)
y_oversampled = pd.DataFrame(y_oversampled, columns=["y"]).astype('int')

# Training
print("\n", "clf1", "\n")
hyp_parameters = {
  "penalty": ["l1", "l2"],
  "C": [1, 10, 100],
  "max_iter": [1000]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_1 = LogisticRegression()
  clf_1.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_1 = clf_1.predict(X_valid)
  cl1_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_1)
  cl1_recall[json.dumps(config)] += recall_score(y_valid, y_pred_1, pos_label=1)

print("\n", "clf2", "\n")
hyp_parameters = {
  "criterion": ["gini", "entropy"],
  "max_depth": [None, 15],
  "max_features": [None, "sqrt"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_2 = DecisionTreeClassifier(**config)
  clf_2.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_2 = clf_2.predict(X_valid)
  cl2_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_2)
  cl2_recall[json.dumps(config)] += recall_score(y_valid, y_pred_2, pos_label=1)

print("\n", "clf3", "\n")
hyp_parameters = {
  "criterion": ["gini", "entropy"],
  "n_estimators": [100],
  "max_depth": [None, 15],
  "max_features": [None, "sqrt"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_3 = RandomForestClassifier(**config)
  clf_3.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_3 = clf_3.predict(X_valid)
  cl3_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_3)
  cl3_recall[json.dumps(config)] += recall_score(y_valid, y_pred_3, pos_label=1)

print("\n", "clf4", "\n")
hyp_parameters = {
  "C": [1, 50],
  "kernel": ["linear", "rbf"],
  "gamma": ["scale", "auto"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_4 = SVC(**config)
  clf_4.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_4 = clf_4.predict(X_valid)
  cl4_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_4)
  cl4_recall[json.dumps(config)] += recall_score(y_valid, y_pred_4, pos_label=1)

print("\n", "TRAINING 3 RESULTS", "\n")
print(cl1_accuracy)
print(cl2_accuracy)
print(cl3_accuracy)
print(cl4_accuracy)

print(cl1_recall)
print(cl2_recall)
print(cl3_recall)
print(cl4_recall)
# Out:
# Training 3
# /usr/local/lib/python3.6/dist-packages/imblearn/utils/_validation.py:93: UserWarning: 'y' should be of types ('binary', 'multiclass', 'multilabel-indicator') only. Got unknown instead.
#   TARGET_KIND, type_of_target(y)))
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
#  clf1
#
# Current training: {'C': 1, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 1, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 10, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 10, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 100, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 100, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#  clf2
#
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': None}
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt'}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': None}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt'}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': None}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt'}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': None}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt'}
#
#  clf3
#
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 100}
#
#  clf4
#
# Current training: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Current training: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Current training: {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# Current training: {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# Current training: {'C': 50, 'gamma': 'scale', 'kernel': 'linear'}
# Current training: {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}
# Current training: {'C': 50, 'gamma': 'auto', 'kernel': 'linear'}
# Current training: {'C': 50, 'gamma': 'auto', 'kernel': 'rbf'}
#
#  TRAINING 3 RESULTS
#
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 2.466601404978775, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 2.466601404978775, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 2.466601404978775, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 2.466601404978775, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 2.466601404978775, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 2.466601404978775}
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 2.527697568193358, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 2.568859439499515, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 2.6495552816287624, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 2.6110240111864784, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 2.5411977101117755, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 2.5591385565636386, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 2.649720595574802, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 2.596188833094453}
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 2.676727711014523, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 2.673430920431074, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 2.686278535835688, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 2.6851266516823227, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 2.6803507648548734, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 2.678373829105285, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 2.688420216231075, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 2.686772580006338}
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 2.5899374555911927, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 2.163744547933589, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 2.5899374555911927, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 2.5184760428970443, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 2.5925737494574705, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 2.163744547933589, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 2.5925737494574705, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 2.5593125997800334}
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 1.8721762094185952, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 1.8721762094185952, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 1.8721762094185952, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 1.8721762094185952, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 1.8721762094185952, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 1.8721762094185952}
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 1.0606835955285772, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 1.0545623749269828, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 1.0664938687846623, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 1.1783616184365124, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 1.082945204414564, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 1.0233143877557818, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 1.072401868349336, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 1.1712164926472057}
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 1.0188300828230465, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 1.0038735155040568, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 1.0948500456426284, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 1.2396382349740247, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 1.0173353145121347, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 1.0068985889653672, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 1.129194179954113, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 1.2470587712693537}
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 1.5902335880880512, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 2.122808654108836, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 1.5902335880880512, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 1.7825789528626035, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 1.5962126613316987, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 2.122808654108836, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 1.5962126613316987, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 1.0323274186706113}

# %%
# Training 4 -------------------------------------------------------------------
print("Training 4")
# Datasets composition
df_train = pd.concat([df_train_valid_1, df_train_valid_4, df_train_valid_3, df_train_valid_5]).sample(frac=1)
df_valid = df_train_valid_2

# Variables separation
y = df_train['y']
X = df_train.drop('y', axis=1)
y_valid = df_valid['y'].astype('int')
X_valid = df_valid.drop('y', axis=1)

# Oversampling
X_oversampled, y_oversampled = SMOTE().fit_resample(X, y)
X_oversampled = pd.DataFrame(X_oversampled, columns=X.columns)
y_oversampled = pd.DataFrame(y_oversampled, columns=["y"]).astype('int')

# Training
print("\n", "clf1", "\n")
hyp_parameters = {
  "penalty": ["l1", "l2"],
  "C": [1, 10, 100],
  "max_iter": [1000]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_1 = LogisticRegression()
  clf_1.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_1 = clf_1.predict(X_valid)
  cl1_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_1)
  cl1_recall[json.dumps(config)] += recall_score(y_valid, y_pred_1, pos_label=1)

print("\n", "clf2", "\n")
hyp_parameters = {
  "criterion": ["gini", "entropy"],
  "max_depth": [None, 15],
  "max_features": [None, "sqrt"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_2 = DecisionTreeClassifier(**config)
  clf_2.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_2 = clf_2.predict(X_valid)
  cl2_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_2)
  cl2_recall[json.dumps(config)] += recall_score(y_valid, y_pred_2, pos_label=1)

print("\n", "clf3", "\n")
hyp_parameters = {
  "criterion": ["gini", "entropy"],
  "n_estimators": [100],
  "max_depth": [None, 15],
  "max_features": [None, "sqrt"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_3 = RandomForestClassifier(**config)
  clf_3.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_3 = clf_3.predict(X_valid)
  cl3_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_3)
  cl3_recall[json.dumps(config)] += recall_score(y_valid, y_pred_3, pos_label=1)

print("\n", "clf4", "\n")
hyp_parameters = {
  "C": [1, 50],
  "kernel": ["linear", "rbf"],
  "gamma": ["scale", "auto"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_4 = SVC(**config)
  clf_4.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_4 = clf_4.predict(X_valid)
  cl4_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_4)
  cl4_recall[json.dumps(config)] += recall_score(y_valid, y_pred_4, pos_label=1)

print("\n", "TRAINING 4 RESULTS", "\n")
print(cl1_accuracy)
print(cl2_accuracy)
print(cl3_accuracy)
print(cl4_accuracy)

print(cl1_recall)
print(cl2_recall)
print(cl3_recall)
print(cl4_recall)
# Out:
# Training 4
# /usr/local/lib/python3.6/dist-packages/imblearn/utils/_validation.py:93: UserWarning: 'y' should be of types ('binary', 'multiclass', 'multilabel-indicator') only. Got unknown instead.
#   TARGET_KIND, type_of_target(y)))
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
#  clf1
#
# Current training: {'C': 1, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 1, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 10, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 10, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 100, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 100, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#  clf2
#
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': None}
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt'}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': None}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt'}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': None}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt'}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': None}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt'}
#
#  clf3
#
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 100}
#
#  clf4
#
# Current training: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Current training: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Current training: {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# Current training: {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# Current training: {'C': 50, 'gamma': 'scale', 'kernel': 'linear'}
# Current training: {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}
# Current training: {'C': 50, 'gamma': 'auto', 'kernel': 'linear'}
# Current training: {'C': 50, 'gamma': 'auto', 'kernel': 'rbf'}
#
#  TRAINING 4 RESULTS
#
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 3.2606705977300106, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 3.2606705977300106, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 3.2606705977300106, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 3.2606705977300106, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 3.2606705977300106, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 3.2606705977300106}
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 3.3787684083910516, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 3.4166353867812282, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 3.5264910312169007, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 3.4823584428174503, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 3.390621103851479, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 3.4141632682605083, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 3.5253383879965483, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 3.448577630458539}
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 3.5696436912451652, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 3.5656879220785207, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 3.582489408982311, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 3.5795253337251562, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 3.573760979022913, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 3.5719487879191236, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 3.583313132211306, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 3.5819949852781665}
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 3.452540420994817, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 2.8808779910966864, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 3.452540420994817, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 3.350601248827852, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 3.4536940130489038, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 2.8808779910966864, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 3.4536940130489038, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 3.4026404416251737}
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 2.522400424665232, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 2.522400424665232, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 2.522400424665232, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 2.522400424665232, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 2.522400424665232, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 2.522400424665232}
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 1.4179332218364995, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 1.395369549814875, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 1.413280116916202, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 1.5774647574499654, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 1.4312262208570155, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 1.3701006358873213, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 1.438620104522729, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 1.5867620830806886}
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 1.3760797091309689, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 1.3521545319465083, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 1.4834898064796986, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 1.6776053500711847, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 1.3656163309545861, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 1.3551796054078187, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 1.5238130140348305, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 1.6865206546774254}
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 2.1432978631254205, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 2.8313288334810336, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 2.1432978631254205, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 2.3999182652691804, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 2.149276936369068, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 2.8313288334810336, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 2.149276936369068, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 1.3716398252475919}

# %%
# Training 5 -------------------------------------------------------------------
print("Training 5")
# Datasets composition
df_train = pd.concat([df_train_valid_4, df_train_valid_2, df_train_valid_3, df_train_valid_5]).sample(frac=1)
df_valid = df_train_valid_1

# Variables separation
y = df_train['y']
X = df_train.drop('y', axis=1)
y_valid = df_valid['y'].astype('int')
X_valid = df_valid.drop('y', axis=1)

# Oversampling
X_oversampled, y_oversampled = SMOTE().fit_resample(X, y)
X_oversampled = pd.DataFrame(X_oversampled, columns=X.columns)
y_oversampled = pd.DataFrame(y_oversampled, columns=["y"]).astype('int')

# Training
print("\n", "clf1", "\n")
hyp_parameters = {
  "penalty": ["l1", "l2"],
  "C": [1, 10, 100],
  "max_iter": [1000]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_1 = LogisticRegression()
  clf_1.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_1 = clf_1.predict(X_valid)
  cl1_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_1)
  cl1_recall[json.dumps(config)] += recall_score(y_valid, y_pred_1, pos_label=1)

print("\n", "clf2", "\n")
hyp_parameters = {
  "criterion": ["gini", "entropy"],
  "max_depth": [None, 15],
  "max_features": [None, "sqrt"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_2 = DecisionTreeClassifier(**config)
  clf_2.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_2 = clf_2.predict(X_valid)
  cl2_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_2)
  cl2_recall[json.dumps(config)] += recall_score(y_valid, y_pred_2, pos_label=1)

print("\n", "clf3", "\n")
hyp_parameters = {
  "criterion": ["gini", "entropy"],
  "n_estimators": [100],
  "max_depth": [None, 15],
  "max_features": [None, "sqrt"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_3 = RandomForestClassifier(**config)
  clf_3.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_3 = clf_3.predict(X_valid)
  cl3_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_3)
  cl3_recall[json.dumps(config)] += recall_score(y_valid, y_pred_3, pos_label=1)

print("\n", "clf4", "\n")
hyp_parameters = {
  "C": [1, 50],
  "kernel": ["linear", "rbf"],
  "gamma": ["scale", "auto"]
  }

for config in ParameterGrid(hyp_parameters):
  print(f"Current training: {config}")
  clf_4 = SVC(**config)
  clf_4.fit(X_oversampled, y_oversampled.values.ravel())
  y_pred_4 = clf_4.predict(X_valid)
  cl4_accuracy[json.dumps(config)] += accuracy_score(y_valid, y_pred_4)
  cl4_recall[json.dumps(config)] += recall_score(y_valid, y_pred_4, pos_label=1)

print("\n", "TRAINING 5 RESULTS", "\n")
print(cl1_accuracy)
print(cl2_accuracy)
print(cl3_accuracy)
print(cl4_accuracy)

print(cl1_recall)
print(cl2_recall)
print(cl3_recall)
print(cl4_recall)
# Out:
# Training 5
# /usr/local/lib/python3.6/dist-packages/imblearn/utils/_validation.py:93: UserWarning: 'y' should be of types ('binary', 'multiclass', 'multilabel-indicator') only. Got unknown instead.
#   TARGET_KIND, type_of_target(y)))
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
#  clf1
#
# Current training: {'C': 1, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 1, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 10, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 10, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 100, 'max_iter': 1000, 'penalty': 'l1'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Current training: {'C': 100, 'max_iter': 1000, 'penalty': 'l2'}
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#  clf2
#
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': None}
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt'}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': None}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt'}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': None}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt'}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': None}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt'}
#
#  clf3
#
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': None, 'n_estimators': 100}
# Current training: {'criterion': 'entropy', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 100}
#
#  clf4
#
# Current training: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Current training: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Current training: {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# Current training: {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# Current training: {'C': 50, 'gamma': 'scale', 'kernel': 'linear'}
# Current training: {'C': 50, 'gamma': 'scale', 'kernel': 'rbf'}
# Current training: {'C': 50, 'gamma': 'auto', 'kernel': 'linear'}
# Current training: {'C': 50, 'gamma': 'auto', 'kernel': 'rbf'}
#
#  TRAINING 5 RESULTS
#
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 4.08917142145324, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 4.08917142145324, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 4.08917142145324, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 4.08917142145324, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 4.08917142145324, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 4.08917142145324}
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 4.218636612674413, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 4.271001119894902, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 4.405568461200426, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 4.346114620741668, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 4.240044497591183, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 4.268693746019981, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 4.405733775146466, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 4.331608931941241}
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 4.458276310685033, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 4.454979520101585, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 4.479688750003728, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 4.472441313955799, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 4.465359002087164, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 4.460251918067394, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 4.4787002821289335, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 4.475405199446206}
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 4.3138254292320495, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 3.6108615166321067, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 4.3138254292320495, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 4.1959060264225805, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 4.315143765931935, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 3.6108615166321067, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 4.315143765931935, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 4.252063835364877}
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 3.138244968760897, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 3.138244968760897, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 3.138244968760897, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 3.138244968760897, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 3.138244968760897, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 3.138244968760897}
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 1.766214238278951, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 1.7645773226100918, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 1.7899617312659777, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 1.9855365063288892, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 1.7914653837867613, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 1.7124025790861255, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 1.8063331090070338, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 1.997823368581436}
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 1.7049287375315667, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 1.6839930969689298, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 1.8691400306949453, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 2.0782032573955496, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 1.694465359355184, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 1.672070487321122, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 1.8915260185191354, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 2.0916028669345255}
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 2.672445845188201, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 3.5263960980550246, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 2.672445845188201, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 2.9858674431466095, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 2.6769301501209366, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 3.5263960980550246, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 2.6769301501209366, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 1.7124470001354841}

# %% [markdown]
# AVERAGE

# %%
cl1_accuracy = {k: v / 5 for k, v in cl1_accuracy.items()}
cl2_accuracy = {k: v / 5 for k, v in cl2_accuracy.items()}
cl3_accuracy = {k: v / 5 for k, v in cl3_accuracy.items()}
cl4_accuracy = {k: v / 5 for k, v in cl4_accuracy.items()}

cl1_recall = {k: v / 5 for k, v in cl1_recall.items()}
cl2_recall = {k: v / 5 for k, v in cl2_recall.items()}
cl3_recall = {k: v / 5 for k, v in cl3_recall.items()}
cl4_recall = {k: v / 5 for k, v in cl4_recall.items()}

# %%
print("Averaged Results", "\n")

print(cl1_accuracy, "\n")
print(cl2_accuracy, "\n")
print(cl3_accuracy, "\n")
print(cl4_accuracy, "\n\n")

print(cl1_recall, "\n")
print(cl2_recall, "\n")
print(cl3_recall, "\n")
print(cl4_recall, "\n")
# Out:
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 0.8178342842906481, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 0.8178342842906481, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 0.8178342842906481, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 0.8178342842906481, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 0.8178342842906481, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 0.8178342842906481}
#
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 0.8437273225348825, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 0.8542002239789804, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 0.8811136922400851, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 0.8692229241483336, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 0.8480088995182365, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 0.8537387492039961, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 0.8811467550292931, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 0.8663217863882482}
#
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 0.8916552621370066, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 0.8909959040203169, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 0.8959377500007457, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 0.8944882627911598, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 0.893071800417433, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 0.8920503836134788, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 0.8957400564257867, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 0.8950810398892411}
#
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 0.8627650858464099, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 0.7221723033264213, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 0.8627650858464099, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 0.839181205284516, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 0.8630287531863869, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 0.7221723033264213, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 0.8630287531863869, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 0.8504127670729755}
#
#
# {'{"C": 1, "max_iter": 1000, "penalty": "l1"}': 0.6276489937521794, '{"C": 1, "max_iter": 1000, "penalty": "l2"}': 0.6276489937521794, '{"C": 10, "max_iter": 1000, "penalty": "l1"}': 0.6276489937521794, '{"C": 10, "max_iter": 1000, "penalty": "l2"}': 0.6276489937521794, '{"C": 100, "max_iter": 1000, "penalty": "l1"}': 0.6276489937521794, '{"C": 100, "max_iter": 1000, "penalty": "l2"}': 0.6276489937521794}
#
# {'{"criterion": "gini", "max_depth": null, "max_features": null}': 0.35324284765579017, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt"}': 0.3529154645220184, '{"criterion": "gini", "max_depth": 15, "max_features": null}': 0.35799234625319554, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}': 0.39710730126577787, '{"criterion": "entropy", "max_depth": null, "max_features": null}': 0.3582930767573523, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}': 0.3424805158172251, '{"criterion": "entropy", "max_depth": 15, "max_features": null}': 0.3612666218014068, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}': 0.3995646737162872}
#
# {'{"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}': 0.34098574750631333, '{"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 0.33679861939378597, '{"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}': 0.37382800613898903, '{"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 0.4156406514791099, '{"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}': 0.3388930718710368, '{"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}': 0.33441409746422446, '{"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}': 0.3783052037038271, '{"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}': 0.4183205733869051}
#
# {'{"C": 1, "gamma": "scale", "kernel": "linear"}': 0.5344891690376402, '{"C": 1, "gamma": "scale", "kernel": "rbf"}': 0.7052792196110049, '{"C": 1, "gamma": "auto", "kernel": "linear"}': 0.5344891690376402, '{"C": 1, "gamma": "auto", "kernel": "rbf"}': 0.5971734886293218, '{"C": 50, "gamma": "scale", "kernel": "linear"}': 0.5353860300241874, '{"C": 50, "gamma": "scale", "kernel": "rbf"}': 0.7052792196110049, '{"C": 50, "gamma": "auto", "kernel": "linear"}': 0.5353860300241874, '{"C": 50, "gamma": "auto", "kernel": "rbf"}': 0.3424894000270968}

# %% [markdown]
# *To avoid re-run*
#
# ---
#
# **Logistic Regression:**
#
# Accuracy:
#
# *   {"C": 1, "max_iter": 1000, "penalty": "l1"}: 0.818
# *   {"C": 1, "max_iter": 1000, "penalty": "l2"}: 0.818
# *   {"C": 10, "max_iter": 1000, "penalty": "l1"}: 0.818
# *   {"C": 10, "max_iter": 1000, "penalty": "l2"}: 0.818
# *   {"C": 100, "max_iter": 1000, "penalty": "l1"}: 0.818
# *   {"C": 100, "max_iter": 1000, "penalty": "l2"}: 0.818
#
# Recall:
#
# *   {"C": 1, "max_iter": 1000, "penalty": "l1"}: 0.628
# *   {"C": 1, "max_iter": 1000, "penalty": "l2"}: 0.628
# *   {"C": 10, "max_iter": 1000, "penalty": "l1"}: 0.628
# *   {"C": 10, "max_iter": 1000, "penalty": "l2"}: 0.628
# *   {"C": 100, "max_iter": 1000, "penalty": "l1"}: 0.628
# *   {"C": 100, "max_iter": 1000, "penalty": "l2"}: 0.628
#
# ---
#
# **Decision Tree:**
#
# Accuracy:
#
# *   {"criterion": "gini", "max_depth": null, "max_features": null}: 0.844
# *   {"criterion": "gini", "max_depth": null, "max_features": "sqrt"}: 0.854
# *   {"criterion": "gini", "max_depth": 15, "max_features": null}: 0.881
# *   {"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}: 0.869
# *   {"criterion": "entropy", "max_depth": null, "max_features": null}: 0.848
# *   {"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}: 0.854
# *   {"criterion": "entropy", "max_depth": 15, "max_features": null}: 0.881
# *   {"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}: 0.866
#
# Recall:
#
# *   {"criterion": "gini", "max_depth": null, "max_features": null}: 0.353
# *   {"criterion": "gini", "max_depth": null, "max_features": "sqrt"}: 0.353
# *   {"criterion": "gini", "max_depth": 15, "max_features": null}: 0.358
# *   {"criterion": "gini", "max_depth": 15, "max_features": "sqrt"}: 0.397
# *   {"criterion": "entropy", "max_depth": null, "max_features": null}: 0.358
# *   {"criterion": "entropy", "max_depth": null, "max_features": "sqrt"}: 0.342
# *   {"criterion": "entropy", "max_depth": 15, "max_features": null}: 0.361
# *   {"criterion": "entropy", "max_depth": 15, "max_features": "sqrt"}: 0.400
#
# ---
#
# **Random Forest:**
#
# Accuracy:
#
# *   {"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}: 0.892
# *   {"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}: 0.891
# *   {"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}: 0.896
# *   {"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}: 0.894
# *   {"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}: 0.893
# *   {"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}: 0.892
# *   {"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}: 0.896
# *   {"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}: 0.89
#
# Recall:
#
# *   {"criterion": "gini", "max_depth": null, "max_features": null, "n_estimators": 100}: 0.341
# *   {"criterion": "gini", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}: 0.337
# *   {"criterion": "gini", "max_depth": 15, "max_features": null, "n_estimators": 100}: 0.374
# *   {"criterion": "gini", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}: 0.416
# *   {"criterion": "entropy", "max_depth": null, "max_features": null, "n_estimators": 100}: 0.339
# *   {"criterion": "entropy", "max_depth": null, "max_features": "sqrt", "n_estimators": 100}: 0.334
# *   {"criterion": "entropy", "max_depth": 15, "max_features": null, "n_estimators": 100}: 0.378
# *   {"criterion": "entropy", "max_depth": 15, "max_features": "sqrt", "n_estimators": 100}: 0.418
#
# ---
#
# **SVM:**
#
# Accuracy:
#
# *   {"C": 1, "gamma": "scale", "kernel": "linear"}: 0.863
# *   {"C": 1, "gamma": "scale", "kernel": "rbf"}: 0.722
# *   {"C": 1, "gamma": "auto", "kernel": "linear"}: 0.863
# *   {"C": 1, "gamma": "auto", "kernel": "rbf"}: 0.839
# *   {"C": 50, "gamma": "scale", "kernel": "linear"}: 0.863
# *   {"C": 50, "gamma": "scale", "kernel": "rbf"}: 0.722
# *   {"C": 50, "gamma": "auto", "kernel": "linear"}: 0.863
# *   {"C": 50, "gamma": "auto", "kernel": "rbf"}: 0.850
#
# Recall:
#
# *   {"C": 1, "gamma": "scale", "kernel": "linear"}: 0.534
# *   {"C": 1, "gamma": "scale", "kernel": "rbf"}: 0.705
# *   {"C": 1, "gamma": "auto", "kernel": "linear"}: 0.534
# *   {"C": 1, "gamma": "auto", "kernel": "rbf"}: 0.597
# *   {"C": 50, "gamma": "scale", "kernel": "linear"}: 0.535
# *   {"C": 50, "gamma": "scale", "kernel": "rbf"}: 0.705
# *   {"C": 50, "gamma": "auto", "kernel": "linear"}: 0.535
# *   {"C": 50, "gamma": "auto", "kernel": "rbf"}: 0.342

# %% [markdown]
# **FINAL TRAINING WITH BEST PARAMETERS, USING ALSO VALIDATION DATA**

# %%
cl1_final_accuracy = 0
cl2_final_accuracy = 0
cl3_final_accuracy = 0
cl4_final_accuracy = 0

cl1_final_recall = 0
cl2_final_recall = 0
cl3_final_recall = 0
cl4_final_recall = 0

# Variables separation
y = df_train_valid['y']
X = df_train_valid.drop('y', axis=1)

# Oversampling
X_oversampled, y_oversampled = SMOTE().fit_resample(X, y)
X_oversampled = pd.DataFrame(X_oversampled, columns=X.columns)
y_oversampled = pd.DataFrame(y_oversampled, columns=["y"]).astype('int')

# Training + Testing
clf_1 = LogisticRegression(C=1, max_iter=1000, penalty="l2")
clf_1.fit(X_oversampled, y_oversampled.values.ravel())
y_pred_1 = clf_1.predict(df_test)
cl1_final_accuracy = accuracy_score(y_test, y_pred_1)
cl1_final_recall = recall_score(y_test, y_pred_1, pos_label=1)


clf_2 = DecisionTreeClassifier(criterion="entropy", max_depth=15, max_features=None)
clf_2.fit(X_oversampled, y_oversampled.values.ravel())
y_pred_2 = clf_2.predict(df_test)
cl2_final_accuracy = accuracy_score(y_test, y_pred_2)
cl2_final_recall = recall_score(y_test, y_pred_2, pos_label=1)


clf_3 = RandomForestClassifier(criterion="entropy", max_depth=15, max_features="sqrt", n_estimators=100)
clf_3.fit(X_oversampled, y_oversampled.values.ravel())
y_pred_3 = clf_3.predict(df_test)
cl3_final_accuracy = accuracy_score(y_test, y_pred_3)
cl3_final_recall = recall_score(y_test, y_pred_3, pos_label=1)


clf_4 = SVC(C=1, gamma="auto", kernel="rbf")
clf_4.fit(X_oversampled, y_oversampled.values.ravel())
y_pred_4 = clf_4.predict(df_test)
cl4_final_accuracy = accuracy_score(y_test, y_pred_4)
cl4_final_recall = recall_score(y_test, y_pred_4, pos_label=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/imblearn/utils/_validation.py:93: UserWarning: 'y' should be of types ('binary', 'multiclass', 'multilabel-indicator') only. Got unknown instead.
#   TARGET_KIND, type_of_target(y)))
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# **EVALUATION**

# %%
print("Test set Results", "\n")

print(f"Logistic Regression: Accuracy = {round(cl1_final_accuracy, 3)}, Recall = {round(cl1_final_recall, 3)}")
print(f"Decision Tree: Accuracy = {round(cl2_final_accuracy, 3)}, Recall = {round(cl2_final_recall, 3)}")
print(f"Random Forest: Accuracy = {round(cl3_final_accuracy, 3)}, Recall = {round(cl3_final_recall, 3)}")
print(f"SVM: Accuracy = {round(cl4_final_accuracy, 3)}, Recall = {round(cl4_final_recall, 3)}")
# Out:
# Test set Results
#
# Logistic Regression: Accuracy = 0.818, Recall = 0.601
# Decision Tree: Accuracy = 0.882, Recall = 0.313
# Random Forest: Accuracy = 0.889, Recall = 0.388
# SVM: Accuracy = 0.849, Recall = 0.566

# %% [markdown]
# Test set Results
#
# *   Logistic Regression: Accuracy = 0.818, Recall = 0.601
# *   Decision Tree: Accuracy = 0.882, Recall = 0.313
# *   Random Forest: Accuracy = 0.889, Recall = 0.388
# *   SVM: Accuracy = 0.849, Recall = 0.566

# %% [markdown]
# **VISUALIZATION**

# %%
import matplotlib.pyplot as plt

fig_2, ax = plt.subplots(1, 2, figsize=(14, 8))
ax[0].bar(['Logistic Regression', 'Decision Tree', 'Random Forest', 'SVM'], [cl1_final_accuracy, cl2_final_accuracy, cl3_final_accuracy, cl4_final_accuracy], color=["#EF3131", "#3151EF", "#2FB62A", "#DF501B"])
ax[0].set_ylim([0, 1])
ax[0].set_xlabel("Models")
ax[0].set_ylabel("Accuracy")
ax[1].bar(['Logistic Regression', 'Decision Tree', 'Random Forest', 'SVM'], [cl1_final_recall, cl2_final_recall, cl3_final_recall, cl4_final_recall], color=["#EF3131", "#3151EF", "#2FB62A", "#DF501B"])
ax[1].set_ylim([0, 1])
ax[1].set_xlabel("Models")
ax[1].set_ylabel("Recall")
plt.tight_layout()
plt.show()
